# %%
# Import Modules

import requests
import json
import pandas as pd

#from config import username, password

from sqlalchemy import create_engine
#engine=create_engine(f"postgresql://Demo:Ronak123@localhost:5432/employees")
#connection=engine.connect()
rds_connection_string = "Demo:ronak123@localhost:5432/value_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
##################################################
# Extracting Data for First Table: countries

# Get API url strings
url_cn = 'http://api.worldbank.org/v2/country/cn?format=json'
url_us = 'http://api.worldbank.org/v2/country/us?format=json'
url_ru = 'http://api.worldbank.org/v2/country/ru?format=json'

# %%
# Check API

print(requests.get(url_cn))
print('----------------------------')
print(requests.get(url_cn).json())
# Out:
# <Response [200]>
# ----------------------------
# [{'page': 1, 'pages': 1, 'per_page': '50', 'total': 1}, [{'id': 'CHN', 'iso2Code': 'CN', 'name': 'China', 'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}, 'adminregion': {'id': 'EAP', 'iso2code': '4E', 'value': 'East Asia & Pacific (excluding high income)'}, 'incomeLevel': {'id': 'UMC', 'iso2code': 'XT', 'value': 'Upper middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Beijing', 'longitude': '116.286', 'latitude': '40.0495'}]]

# %%
# Extracting data for all three countries

response_cn = requests.get(url_cn).json()
response_us = requests.get(url_us).json()
response_ru = requests.get(url_ru).json()

# %%
# Transforming data by creating lists to zip into a DF

country_name = []
country_id = []

#append country id's
country_name.append(response_us[1][0]['name'])
country_name.append(response_cn[1][0]['name'])
country_name.append(response_ru[1][0]['name'])

# append country names
country_id.append(response_us[1][0]['id'])
country_id.append(response_cn[1][0]['id'])
country_id.append(response_ru[1][0]['id'])

# %%
# Transforming data by zipping the lists, creating the DF using pandas...
# ... & renaming the columns to be ready to load into new sequel DB

dict_c = zip(country_id, country_name)
df = pd.DataFrame(dict_c)
countries = df.rename(columns={0: 'country_code', 1: 'country_name'})
countries

### COUNTRY TABLE READY ###
# Out:
#   country_code        country_name
# 0          USA       United States
# 1          CHN               China
# 2          RUS  Russian Federation

# %%
##################################################
# Extracting & Transforming Data for Second Table: indicators

Indicators_df = pd.read_csv("C:/Users/Ronnie/ETL_Project/Indicators.csv")
Indicators_df.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
# Transforming data by dropping unwanted columns...

Ind1 =Indicators_df.drop(['CountryName', 'CountryCode', 'Year', 'Value'], axis=1)
Ind1
# Out:
#                                              IndicatorName      IndicatorCode
# 0        Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1        Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2        Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3        Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4              Arms exports (SIPRI trend indicator values)     MS.MIL.XPRT.KD
# 5              Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# 6                     Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
# 7                                       CO2 emissions (kt)     EN.ATM.CO2E.KT
# 8                   CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 9        CO2 emissions from gaseous fuel consumption (%...  EN.ATM.CO2E.GF.ZS
# 10       CO2 emissions from liquid fuel consumption (% ...  EN.ATM.CO2E.LF.ZS
# 11         CO2 emissions from liquid fuel consumption (kt)  EN.ATM.CO2E.LF.KT
# 12       CO2 emissions from solid fuel consumption (% o...  EN.ATM.CO2E.SF.ZS
# 13                    Death rate, crude (per 1,000 people)     SP.DYN.CDRT.IN
# 14                Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 15                           Fixed telephone subscriptions        IT.MLT.MAIN
# 16          Fixed telephone subscriptions (per 100 people)     IT.MLT.MAIN.P2
# 17                        Hospital beds (per 1,000 people)     SH.MED.BEDS.ZS
# 18           International migrant stock (% of population)     SM.POP.TOTL.ZS
# 19                      International migrant stock, total        SM.POP.TOTL
# 20                Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN
# 21                  Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN
# 22                 Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 23                       Merchandise exports (current US$)  TX.VAL.MRCH.CD.WT
# 24       Merchandise exports by the reporting economy (...  TX.VAL.MRCH.WL.CD
# 25       Merchandise exports by the reporting economy, ...  TX.VAL.MRCH.RS.ZS
# 26       Merchandise exports to developing economies in...  TX.VAL.MRCH.R1.ZS
# 27       Merchandise exports to developing economies in...  TX.VAL.MRCH.R3.ZS
# 28       Merchandise exports to developing economies in...  TX.VAL.MRCH.R4.ZS
# 29       Merchandise exports to developing economies in...  TX.VAL.MRCH.R5.ZS
# ...                                                    ...                ...
# 5656428               PPG, multilateral (INT, current US$)     DT.INT.MLAT.CD
# 5656429         PPG, official creditors (AMT, current US$)     DT.AMT.OFFT.CD
# 5656430         PPG, official creditors (DIS, current US$)     DT.DIS.OFFT.CD
# 5656431         PPG, official creditors (INT, current US$)     DT.INT.OFFT.CD
# 5656432    PPG, other private creditors (AMT, current US$)     DT.AMT.PROP.CD
# 5656433    PPG, other private creditors (DIS, current US$)     DT.DIS.PROP.CD
# 5656434    PPG, other private creditors (INT, current US$)     DT.INT.PROP.CD
# 5656435          PPG, private creditors (AMT, current US$)     DT.AMT.PRVT.CD
# 5656436          PPG, private creditors (DIS, current US$)     DT.DIS.PRVT.CD
# 5656437          PPG, private creditors (INT, current US$)     DT.INT.PRVT.CD
# 5656438  Principal repayments on external debt, long-te...     DT.AMT.DLXF.CD
# 5656439  Principal repayments on external debt, private...     DT.AMT.DPNG.CD
# 5656440       Private credit bureau coverage (% of adults)     IC.CRD.PRVT.ZS
# 5656441           Procedures to build a warehouse (number)        IC.WRH.PROC
# 5656442           Procedures to register property (number)        IC.PRP.PROC
# 5656443               Profit tax (% of commercial profits)  IC.TAX.PRFT.CP.ZS
# 5656444  Proportion of seats held by women in national ...     SG.GEN.PARL.ZS
# 5656445      Public credit registry coverage (% of adults)     IC.CRD.PUBL.ZS
# 5656446  Source data assessment of statistical capacity...        IQ.SCI.SRCE
# 5656447  Start-up procedures to register a business (nu...        IC.REG.PROC
# 5656448  Strength of legal rights index (0=weak to 12=s...     IC.LGL.CRED.XQ
# 5656449                              Tax payments (number)        IC.TAX.PAYM
# 5656450          Time required to build a warehouse (days)        IC.WRH.DURS
# 5656451         Time required to enforce a contract (days)        IC.LGL.DURS
# 5656452            Time required to get electricity (days)        IC.ELC.TIME
# 5656453          Time required to register property (days)        IC.PRP.DURS
# 5656454           Time required to start a business (days)        IC.REG.DURS
# 5656455              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 5656456                 Time to resolve insolvency (years)        IC.ISV.DURS
# 5656457           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
# [5656458 rows x 2 columns]

# %%
# ...& Dropping duplicate values

Ind2 = Ind1.drop_duplicates(subset='IndicatorCode', keep="first")
ind_df = Ind2.rename(columns={'IndicatorName':'indicator_name',
                             'IndicatorCode': 'indicator_code'})
ind_df

### INDICATOR TABLE READY ###
# Out:
#                                             indicator_name     indicator_code
# 0        Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1        Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2        Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3        Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4              Arms exports (SIPRI trend indicator values)     MS.MIL.XPRT.KD
# 5              Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# 6                     Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
# 7                                       CO2 emissions (kt)     EN.ATM.CO2E.KT
# 8                   CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 9        CO2 emissions from gaseous fuel consumption (%...  EN.ATM.CO2E.GF.ZS
# 10       CO2 emissions from liquid fuel consumption (% ...  EN.ATM.CO2E.LF.ZS
# 11         CO2 emissions from liquid fuel consumption (kt)  EN.ATM.CO2E.LF.KT
# 12       CO2 emissions from solid fuel consumption (% o...  EN.ATM.CO2E.SF.ZS
# 13                    Death rate, crude (per 1,000 people)     SP.DYN.CDRT.IN
# 14                Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 15                           Fixed telephone subscriptions        IT.MLT.MAIN
# 16          Fixed telephone subscriptions (per 100 people)     IT.MLT.MAIN.P2
# 17                        Hospital beds (per 1,000 people)     SH.MED.BEDS.ZS
# 18           International migrant stock (% of population)     SM.POP.TOTL.ZS
# 19                      International migrant stock, total        SM.POP.TOTL
# 20                Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN
# 21                  Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN
# 22                 Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 23                       Merchandise exports (current US$)  TX.VAL.MRCH.CD.WT
# 24       Merchandise exports by the reporting economy (...  TX.VAL.MRCH.WL.CD
# 25       Merchandise exports by the reporting economy, ...  TX.VAL.MRCH.RS.ZS
# 26       Merchandise exports to developing economies in...  TX.VAL.MRCH.R1.ZS
# 27       Merchandise exports to developing economies in...  TX.VAL.MRCH.R3.ZS
# 28       Merchandise exports to developing economies in...  TX.VAL.MRCH.R4.ZS
# 29       Merchandise exports to developing economies in...  TX.VAL.MRCH.R5.ZS
# ...                                                    ...                ...
# 4302388  Net official flows from UN agencies, UNPBF (cu...     DT.NFL.UNPB.CD
# 4332531         Firms with female top manager (% of firms)     IC.FRM.FEMM.ZS
# 4450537  Presence of peace keepers (number of troops, p...     VC.PKP.TOTL.UN
# 4480973  Net bilateral aid flows from DAC donors, Slove...     DC.DAC.SVNL.CD
# 4482722  Net official flows from UN agencies, UNECE (cu...     DT.NFL.UNEC.CD
# 4660539  Distance to frontier score (0=lowest performan...     IC.BUS.DFRN.XQ
# 4660922            Time required to get electricity (days)        IC.ELC.TIME
# 4661370       Point-of-sale terminals (per 100,000 adults)     FB.POS.TOTL.P5
# 4662524  Net official flows from UN agencies, WHO (curr...     DT.NFL.WHOL.CD
# 4682243  Droughts, floods, extreme temperatures (% of p...     EN.CLC.MDAT.ZS
# 4771659  Annualized average growth rate in per capita r...     SI.SPR.PC40.ZG
# 4771660  Annualized average growth rate in per capita r...     SI.SPR.PCAP.ZG
# 4839019  Access to non-solid fuel, rural (% of rural po...  EG.NSF.ACCS.RU.ZS
# 4839020  Access to non-solid fuel, urban (% of urban po...  EG.NSF.ACCS.UR.ZS
# 5049412  Disaster risk reduction progress score (1-5 sc...     EN.CLC.DRSK.XQ
# 5377516  Depth of credit information index (0=low to 8=...     IC.CRD.INFO.XQ
# 5377666  Labor tax and contributions (% of commercial p...  IC.TAX.LABR.CP.ZS
# 5377840               Profit tax (% of commercial profits)  IC.TAX.PRFT.CP.ZS
# 5377866  Strength of legal rights index (0=weak to 12=s...     IC.LGL.CRED.XQ
# 5379367                 Time to resolve insolvency (years)        IC.ISV.DURS
# 5534353  Diabetes prevalence (% of population ages 20 t...     SH.STA.DIAB.ZS
# 5534357  Ease of doing business index (1=most business-...     IC.BUS.EASE.XQ
# 5534489  Other taxes payable by businesses (% of commer...  IC.TAX.OTHR.CP.ZS
# 5535827       Present value of external debt (current US$)     DT.DOD.PVLX.CD
# 5546801          Present value of external debt (% of GNI)  DT.DOD.PVLX.GN.ZS
# 5547405  Present value of external debt (% of exports o...  DT.DOD.PVLX.EX.ZS
# 5641696                           Bird species, threatened     EN.BIR.THRD.NO
# 5641702                           Fish species, threatened     EN.FSH.THRD.NO
# 5641712                         Mammal species, threatened     EN.MAM.THRD.NO
# 5641723                 Plant species (higher), threatened     EN.HPT.THRD.NO
#
# [1344 rows x 2 columns]

# %%
##################################################
# Transforming data from CSV file for first VALUE table, DATES (1960-2015)

# Performing loc to isolate RU, CN, US rows
reset_ind = Indicators_df.set_index('CountryName')
us_ru_cn_df = reset_ind.loc[['China', 'United States', 'Russian Federation'],:]

# Dropping IndicatorName column
value_table = pd.DataFrame(us_ru_cn_df, columns=['CountryCode', 'IndicatorCode', 'Value', 'Year'])
value_table= value_table.dropna()
value_table
# Out:
#                    CountryCode      IndicatorCode         Value  Year
# CountryName
# China                      CHN        SP.ADO.TFRT  6.803320e+01  1960
# China                      CHN        SP.POP.DPND  7.732207e+01  1960
# China                      CHN     SP.POP.DPND.OL  6.472535e+00  1960
# China                      CHN     SP.POP.DPND.YG  7.084954e+01  1960
# China                      CHN     NV.AGR.TOTL.ZS  2.338367e+01  1960
# China                      CHN     NV.AGR.TOTL.KD  4.069809e+10  1960
# China                      CHN     NV.AGR.TOTL.KN  2.707777e+11  1960
# China                      CHN     NV.AGR.TOTL.CN  3.407000e+10  1960
# China                      CHN     NV.AGR.TOTL.CD  1.383942e+10  1960
# China                      CHN     MS.MIL.XPRT.KD  2.850000e+08  1960
# China                      CHN     MS.MIL.MPRT.KD  2.431000e+09  1960
# China                      CHN     SP.DYN.CBRT.IN  2.086000e+01  1960
# China                      CHN     NE.GDI.STKB.CN  1.020000e+10  1960
# China                      CHN     NE.GDI.STKB.CD  4.143294e+09  1960
# China                      CHN  EN.ATM.CO2E.KD.GD  9.657282e+00  1960
# China                      CHN     EN.ATM.CO2E.KT  7.807263e+05  1960
# China                      CHN     EN.ATM.CO2E.PC  1.170381e+00  1960
# China                      CHN  EN.ATM.CO2E.GF.ZS  2.555118e-01  1960
# China                      CHN  EN.ATM.CO2E.GF.KT  1.994848e+03  1960
# China                      CHN  EN.ATM.CO2E.LF.ZS  2.947310e+00  1960
# China                      CHN  EN.ATM.CO2E.LF.KT  2.301042e+04  1960
# China                      CHN  EN.ATM.CO2E.SF.ZS  9.593483e+01  1960
# China                      CHN  EN.ATM.CO2E.SF.KT  7.489884e+05  1960
# China                      CHN     SP.DYN.CDRT.IN  2.543000e+01  1960
# China                      CHN        PA.NUS.ATLS  2.461809e+00  1960
# China                      CHN     NY.GDP.DISC.CN -4.880000e+09  1960
# China                      CHN     NE.EXP.GNFS.ZS  4.344544e+00  1960
# China                      CHN     NE.EXP.GNFS.CN  6.330000e+09  1960
# China                      CHN     NE.EXP.GNFS.CD  2.571280e+09  1960
# China                      CHN     NE.RSB.GNFS.ZS -1.235415e-01  1960
# ...                        ...                ...           ...   ...
# Russian Federation         RUS     EN.MAM.THRD.NO  2.900000e+01  2015
# Russian Federation         RUS        SH.STA.MMRT  2.500000e+01  2015
# Russian Federation         RUS     SP.DYN.IMRT.IN  8.200000e+00  2015
# Russian Federation         RUS  SP.DYN.IMRT.FE.IN  7.200000e+00  2015
# Russian Federation         RUS  SP.DYN.IMRT.MA.IN  9.100000e+00  2015
# Russian Federation         RUS        SH.DYN.NMRT  5.000000e+00  2015
# Russian Federation         RUS        SH.DYN.MORT  9.600000e+00  2015
# Russian Federation         RUS     SH.DYN.MORT.FE  8.400000e+00  2015
# Russian Federation         RUS     SH.DYN.MORT.MA  1.060000e+01  2015
# Russian Federation         RUS        SH.DTH.IMRT  1.598900e+04  2015
# Russian Federation         RUS        SH.MMR.DTHS  4.500000e+02  2015
# Russian Federation         RUS        SH.DTH.NMRT  9.741000e+03  2015
# Russian Federation         RUS        SH.DTH.MORT  1.854200e+04  2015
# Russian Federation         RUS     EN.HPT.THRD.NO  5.900000e+01  2015
# Russian Federation         RUS     IC.CRD.PRVT.ZS  7.020000e+01  2015
# Russian Federation         RUS        IC.WRH.PROC  1.900000e+01  2015
# Russian Federation         RUS        IC.PRP.PROC  3.000000e+00  2015
# Russian Federation         RUS     SG.GEN.PARL.ZS  1.355556e+01  2015
# Russian Federation         RUS     IC.CRD.PUBL.ZS  0.000000e+00  2015
# Russian Federation         RUS        IC.REG.PROC  4.400000e+00  2015
# Russian Federation         RUS     IC.LGL.CRED.XQ  6.000000e+00  2015
# Russian Federation         RUS        IC.TAX.PAYM  7.000000e+00  2015
# Russian Federation         RUS        IC.WRH.DURS  2.635000e+02  2015
# Russian Federation         RUS        IC.LGL.DURS  3.070000e+02  2015
# Russian Federation         RUS        IC.ELC.TIME  1.605000e+02  2015
# Russian Federation         RUS        IC.PRP.DURS  1.500000e+01  2015
# Russian Federation         RUS        IC.REG.DURS  1.050000e+01  2015
# Russian Federation         RUS        IC.TAX.DURS  1.680000e+02  2015
# Russian Federation         RUS        IC.ISV.DURS  2.000000e+00  2015
# Russian Federation         RUS  IC.TAX.TOTL.CP.ZS  4.700000e+01  2015
#
# [71267 rows x 4 columns]

# %%
value_table_reset = value_table.reset_index()
value_table_reset
# Out:
#               CountryName CountryCode      IndicatorCode         Value  Year
# 0                   China         CHN        SP.ADO.TFRT  6.803320e+01  1960
# 1                   China         CHN        SP.POP.DPND  7.732207e+01  1960
# 2                   China         CHN     SP.POP.DPND.OL  6.472535e+00  1960
# 3                   China         CHN     SP.POP.DPND.YG  7.084954e+01  1960
# 4                   China         CHN     NV.AGR.TOTL.ZS  2.338367e+01  1960
# 5                   China         CHN     NV.AGR.TOTL.KD  4.069809e+10  1960
# 6                   China         CHN     NV.AGR.TOTL.KN  2.707777e+11  1960
# 7                   China         CHN     NV.AGR.TOTL.CN  3.407000e+10  1960
# 8                   China         CHN     NV.AGR.TOTL.CD  1.383942e+10  1960
# 9                   China         CHN     MS.MIL.XPRT.KD  2.850000e+08  1960
# 10                  China         CHN     MS.MIL.MPRT.KD  2.431000e+09  1960
# 11                  China         CHN     SP.DYN.CBRT.IN  2.086000e+01  1960
# 12                  China         CHN     NE.GDI.STKB.CN  1.020000e+10  1960
# 13                  China         CHN     NE.GDI.STKB.CD  4.143294e+09  1960
# 14                  China         CHN  EN.ATM.CO2E.KD.GD  9.657282e+00  1960
# 15                  China         CHN     EN.ATM.CO2E.KT  7.807263e+05  1960
# 16                  China         CHN     EN.ATM.CO2E.PC  1.170381e+00  1960
# 17                  China         CHN  EN.ATM.CO2E.GF.ZS  2.555118e-01  1960
# 18                  China         CHN  EN.ATM.CO2E.GF.KT  1.994848e+03  1960
# 19                  China         CHN  EN.ATM.CO2E.LF.ZS  2.947310e+00  1960
# 20                  China         CHN  EN.ATM.CO2E.LF.KT  2.301042e+04  1960
# 21                  China         CHN  EN.ATM.CO2E.SF.ZS  9.593483e+01  1960
# 22                  China         CHN  EN.ATM.CO2E.SF.KT  7.489884e+05  1960
# 23                  China         CHN     SP.DYN.CDRT.IN  2.543000e+01  1960
# 24                  China         CHN        PA.NUS.ATLS  2.461809e+00  1960
# 25                  China         CHN     NY.GDP.DISC.CN -4.880000e+09  1960
# 26                  China         CHN     NE.EXP.GNFS.ZS  4.344544e+00  1960
# 27                  China         CHN     NE.EXP.GNFS.CN  6.330000e+09  1960
# 28                  China         CHN     NE.EXP.GNFS.CD  2.571280e+09  1960
# 29                  China         CHN     NE.RSB.GNFS.ZS -1.235415e-01  1960
# ...                   ...         ...                ...           ...   ...
# 71237  Russian Federation         RUS     EN.MAM.THRD.NO  2.900000e+01  2015
# 71238  Russian Federation         RUS        SH.STA.MMRT  2.500000e+01  2015
# 71239  Russian Federation         RUS     SP.DYN.IMRT.IN  8.200000e+00  2015
# 71240  Russian Federation         RUS  SP.DYN.IMRT.FE.IN  7.200000e+00  2015
# 71241  Russian Federation         RUS  SP.DYN.IMRT.MA.IN  9.100000e+00  2015
# 71242  Russian Federation         RUS        SH.DYN.NMRT  5.000000e+00  2015
# 71243  Russian Federation         RUS        SH.DYN.MORT  9.600000e+00  2015
# 71244  Russian Federation         RUS     SH.DYN.MORT.FE  8.400000e+00  2015
# 71245  Russian Federation         RUS     SH.DYN.MORT.MA  1.060000e+01  2015
# 71246  Russian Federation         RUS        SH.DTH.IMRT  1.598900e+04  2015
# 71247  Russian Federation         RUS        SH.MMR.DTHS  4.500000e+02  2015
# 71248  Russian Federation         RUS        SH.DTH.NMRT  9.741000e+03  2015
# 71249  Russian Federation         RUS        SH.DTH.MORT  1.854200e+04  2015
# 71250  Russian Federation         RUS     EN.HPT.THRD.NO  5.900000e+01  2015
# 71251  Russian Federation         RUS     IC.CRD.PRVT.ZS  7.020000e+01  2015
# 71252  Russian Federation         RUS        IC.WRH.PROC  1.900000e+01  2015
# 71253  Russian Federation         RUS        IC.PRP.PROC  3.000000e+00  2015
# 71254  Russian Federation         RUS     SG.GEN.PARL.ZS  1.355556e+01  2015
# 71255  Russian Federation         RUS     IC.CRD.PUBL.ZS  0.000000e+00  2015
# 71256  Russian Federation         RUS        IC.REG.PROC  4.400000e+00  2015
# 71257  Russian Federation         RUS     IC.LGL.CRED.XQ  6.000000e+00  2015
# 71258  Russian Federation         RUS        IC.TAX.PAYM  7.000000e+00  2015
# 71259  Russian Federation         RUS        IC.WRH.DURS  2.635000e+02  2015
# 71260  Russian Federation         RUS        IC.LGL.DURS  3.070000e+02  2015
# 71261  Russian Federation         RUS        IC.ELC.TIME  1.605000e+02  2015
# 71262  Russian Federation         RUS        IC.PRP.DURS  1.500000e+01  2015
# 71263  Russian Federation         RUS        IC.REG.DURS  1.050000e+01  2015
# 71264  Russian Federation         RUS        IC.TAX.DURS  1.680000e+02  2015
# 71265  Russian Federation         RUS        IC.ISV.DURS  2.000000e+00  2015
# 71266  Russian Federation         RUS  IC.TAX.TOTL.CP.ZS  4.700000e+01  2015
#
# [71267 rows x 5 columns]

# %%
value_csv_df = value_table_reset.rename(columns={'CountryName': 'country_name',
                                            'CountryCode': 'country_code',
                                            'IndicatorCode': 'indicator_code',
                                            'Value': 'value',
                                            'Year': 'year'})
value_csv_df
# Out:
#              country_name country_code     indicator_code         value  year
# 0                   China          CHN        SP.ADO.TFRT  6.803320e+01  1960
# 1                   China          CHN        SP.POP.DPND  7.732207e+01  1960
# 2                   China          CHN     SP.POP.DPND.OL  6.472535e+00  1960
# 3                   China          CHN     SP.POP.DPND.YG  7.084954e+01  1960
# 4                   China          CHN     NV.AGR.TOTL.ZS  2.338367e+01  1960
# 5                   China          CHN     NV.AGR.TOTL.KD  4.069809e+10  1960
# 6                   China          CHN     NV.AGR.TOTL.KN  2.707777e+11  1960
# 7                   China          CHN     NV.AGR.TOTL.CN  3.407000e+10  1960
# 8                   China          CHN     NV.AGR.TOTL.CD  1.383942e+10  1960
# 9                   China          CHN     MS.MIL.XPRT.KD  2.850000e+08  1960
# 10                  China          CHN     MS.MIL.MPRT.KD  2.431000e+09  1960
# 11                  China          CHN     SP.DYN.CBRT.IN  2.086000e+01  1960
# 12                  China          CHN     NE.GDI.STKB.CN  1.020000e+10  1960
# 13                  China          CHN     NE.GDI.STKB.CD  4.143294e+09  1960
# 14                  China          CHN  EN.ATM.CO2E.KD.GD  9.657282e+00  1960
# 15                  China          CHN     EN.ATM.CO2E.KT  7.807263e+05  1960
# 16                  China          CHN     EN.ATM.CO2E.PC  1.170381e+00  1960
# 17                  China          CHN  EN.ATM.CO2E.GF.ZS  2.555118e-01  1960
# 18                  China          CHN  EN.ATM.CO2E.GF.KT  1.994848e+03  1960
# 19                  China          CHN  EN.ATM.CO2E.LF.ZS  2.947310e+00  1960
# 20                  China          CHN  EN.ATM.CO2E.LF.KT  2.301042e+04  1960
# 21                  China          CHN  EN.ATM.CO2E.SF.ZS  9.593483e+01  1960
# 22                  China          CHN  EN.ATM.CO2E.SF.KT  7.489884e+05  1960
# 23                  China          CHN     SP.DYN.CDRT.IN  2.543000e+01  1960
# 24                  China          CHN        PA.NUS.ATLS  2.461809e+00  1960
# 25                  China          CHN     NY.GDP.DISC.CN -4.880000e+09  1960
# 26                  China          CHN     NE.EXP.GNFS.ZS  4.344544e+00  1960
# 27                  China          CHN     NE.EXP.GNFS.CN  6.330000e+09  1960
# 28                  China          CHN     NE.EXP.GNFS.CD  2.571280e+09  1960
# 29                  China          CHN     NE.RSB.GNFS.ZS -1.235415e-01  1960
# ...                   ...          ...                ...           ...   ...
# 71237  Russian Federation          RUS     EN.MAM.THRD.NO  2.900000e+01  2015
# 71238  Russian Federation          RUS        SH.STA.MMRT  2.500000e+01  2015
# 71239  Russian Federation          RUS     SP.DYN.IMRT.IN  8.200000e+00  2015
# 71240  Russian Federation          RUS  SP.DYN.IMRT.FE.IN  7.200000e+00  2015
# 71241  Russian Federation          RUS  SP.DYN.IMRT.MA.IN  9.100000e+00  2015
# 71242  Russian Federation          RUS        SH.DYN.NMRT  5.000000e+00  2015
# 71243  Russian Federation          RUS        SH.DYN.MORT  9.600000e+00  2015
# 71244  Russian Federation          RUS     SH.DYN.MORT.FE  8.400000e+00  2015
# 71245  Russian Federation          RUS     SH.DYN.MORT.MA  1.060000e+01  2015
# 71246  Russian Federation          RUS        SH.DTH.IMRT  1.598900e+04  2015
# 71247  Russian Federation          RUS        SH.MMR.DTHS  4.500000e+02  2015
# 71248  Russian Federation          RUS        SH.DTH.NMRT  9.741000e+03  2015
# 71249  Russian Federation          RUS        SH.DTH.MORT  1.854200e+04  2015
# 71250  Russian Federation          RUS     EN.HPT.THRD.NO  5.900000e+01  2015
# 71251  Russian Federation          RUS     IC.CRD.PRVT.ZS  7.020000e+01  2015
# 71252  Russian Federation          RUS        IC.WRH.PROC  1.900000e+01  2015
# 71253  Russian Federation          RUS        IC.PRP.PROC  3.000000e+00  2015
# 71254  Russian Federation          RUS     SG.GEN.PARL.ZS  1.355556e+01  2015
# 71255  Russian Federation          RUS     IC.CRD.PUBL.ZS  0.000000e+00  2015
# 71256  Russian Federation          RUS        IC.REG.PROC  4.400000e+00  2015
# 71257  Russian Federation          RUS     IC.LGL.CRED.XQ  6.000000e+00  2015
# 71258  Russian Federation          RUS        IC.TAX.PAYM  7.000000e+00  2015
# 71259  Russian Federation          RUS        IC.WRH.DURS  2.635000e+02  2015
# 71260  Russian Federation          RUS        IC.LGL.DURS  3.070000e+02  2015
# 71261  Russian Federation          RUS        IC.ELC.TIME  1.605000e+02  2015
# 71262  Russian Federation          RUS        IC.PRP.DURS  1.500000e+01  2015
# 71263  Russian Federation          RUS        IC.REG.DURS  1.050000e+01  2015
# 71264  Russian Federation          RUS        IC.TAX.DURS  1.680000e+02  2015
# 71265  Russian Federation          RUS        IC.ISV.DURS  2.000000e+00  2015
# 71266  Russian Federation          RUS  IC.TAX.TOTL.CP.ZS  4.700000e+01  2015
#
# [71267 rows x 5 columns]

# %%
##################################################
# Getting data for second VALUE table, DATEs (2016-2019)

# Importing new modules for API extraction

from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET

# %%
# Creating new variables

all_response = []
date = '2016:2019'

# %%
# Getting the indicator url for extraction

indicator_url = "https://data.worldbank.org/indicator"

# %%
# Extracting using Requests & Beautiful Soup

response = requests.get(indicator_url)
soup = BeautifulSoup(response.text, 'html.parser')
results = soup.find_all('li')

# %%
# Looping to get indicators

indicator_list = []
for result in results:

    try:
        indicator = result.a["href"]
        
        if "view=chart" in indicator:
            print(indicator)
            indicator_list.append(indicator)
            
    except AttributeError as e:
        print(e)
# Out:
# /indicator/AG.LND.IRIG.AG.ZS?view=chart
# /indicator/AG.LND.AGRI.ZS?view=chart
# /indicator/AG.LND.TRAC.ZS?view=chart
# /indicator/NV.AGR.TOTL.ZS?view=chart
# /indicator/AG.LND.ARBL.ZS?view=chart
# /indicator/AG.LND.ARBL.HA.PC?view=chart
# /indicator/AG.YLD.CREL.KG?view=chart
# /indicator/AG.PRD.CROP.XD?view=chart
# /indicator/SL.AGR.EMPL.FE.ZS?view=chart
# /indicator/SL.AGR.EMPL.MA.ZS?view=chart
# /indicator/AG.CON.FERT.ZS?view=chart
# /indicator/AG.PRD.FOOD.XD?view=chart
# /indicator/AG.LND.FRST.ZS?view=chart
# /indicator/AG.LND.FRST.K2?view=chart
# /indicator/AG.LND.TOTL.K2?view=chart
# /indicator/AG.LND.CREL.HA?view=chart
# /indicator/AG.PRD.LVSK.XD?view=chart
# /indicator/AG.LND.CROP.ZS?view=chart
# /indicator/SP.RUR.TOTL?view=chart
# /indicator/SP.RUR.TOTL.ZS?view=chart
# /indicator/SI.POV.RUGP?view=chart
# /indicator/SI.POV.RUHC?view=chart
# /indicator/AG.SRF.TOTL.K2?view=chart
# /indicator/BX.GRT.EXTA.CD.WD?view=chart
# /indicator/SH.TBS.INCD?view=chart
# /indicator/SI.DST.FRST.20?view=chart
# /indicator/SH.STA.MMRT?view=chart
# /indicator/SH.DYN.MORT?view=chart
# /indicator/DT.ODA.ODAT.GN.ZS?view=chart
# /indicator/DT.ODA.ODAT.XP.ZS?view=chart
# /indicator/DT.ODA.ODAT.GI.ZS?view=chart
# /indicator/DT.ODA.ODAT.MP.ZS?view=chart
# /indicator/DT.ODA.ODAT.PC.ZS?view=chart
# /indicator/SM.POP.NETM?view=chart
# /indicator/DT.ODA.ODAT.CD?view=chart
# /indicator/SI.POV.DDAY?view=chart
# /indicator/SH.STA.ANVC.ZS?view=chart
# /indicator/SH.DYN.AIDS.ZS?view=chart
# /indicator/SH.STA.STNT.ZS?view=chart
# /indicator/SE.PRM.CMPT.ZS?view=chart
# /indicator/SE.ENR.PRSC.FM.ZS?view=chart
# /indicator/BX.GRT.TECH.CD.WD?view=chart
# /indicator/EG.ELC.ACCS.ZS?view=chart
# /indicator/AG.LND.IRIG.AG.ZS?view=chart
# /indicator/AG.LND.AGRI.ZS?view=chart
# /indicator/NV.AGR.TOTL.ZS?view=chart
# /indicator/ER.H2O.FWTL.ZS?view=chart
# /indicator/ER.H2O.FWTL.K3?view=chart
# /indicator/AG.LND.ARBL.ZS?view=chart
# /indicator/EN.ATM.CO2E.KT?view=chart
# /indicator/EN.ATM.CO2E.PC?view=chart
# /indicator/IQ.CPA.PUBS.XQ?view=chart
# /indicator/AG.YLD.CREL.KG?view=chart
# /indicator/IC.BUS.EASE.XQ?view=chart
# /indicator/EG.USE.ELEC.KH.PC?view=chart
# /indicator/EG.USE.PCAP.KG.OE?view=chart
# /indicator/AG.LND.FRST.ZS?view=chart
# /indicator/AG.LND.FRST.K2?view=chart
# /indicator/AG.LND.EL5M.ZS?view=chart
# /indicator/EN.ATM.METH.KT.CE?view=chart
# /indicator/SH.DYN.MORT?view=chart
# /indicator/EN.ATM.NOXE.KT.CE?view=chart
# /indicator/SP.POP.GROW?view=chart
# /indicator/EN.URB.MCTY.TL.ZS?view=chart
# /indicator/EN.POP.EL5M.ZS?view=chart
# /indicator/SP.POP.TOTL?view=chart
# /indicator/SI.POV.DDAY?view=chart
# /indicator/SH.STA.MALN.ZS?view=chart
# /indicator/SE.PRM.CMPT.ZS?view=chart
# /indicator/EG.ELC.RNEW.ZS?view=chart
# /indicator/EG.FEC.RNEW.ZS?view=chart
# /indicator/SE.ENR.PRSC.FM.ZS?view=chart
# /indicator/ER.PTD.TOTL.ZS?view=chart
# /indicator/EN.ATM.GHGT.KT.CE?view=chart
# /indicator/SP.URB.TOTL?view=chart
# /indicator/SP.URB.TOTL.IN.ZS?view=chart
# /indicator/NY.ADJ.SVNG.GN.ZS?view=chart
# /indicator/NV.AGR.TOTL.ZS?view=chart
# /indicator/GC.DOD.TOTL.GD.ZS?view=chart
# /indicator/BM.GSR.ROYL.CD?view=chart
# /indicator/BX.GSR.ROYL.CD?view=chart
# /indicator/BN.CAB.XOKA.CD?view=chart
# /indicator/GC.XPN.TOTL.GD.ZS?view=chart
# /indicator/NE.EXP.GNFS.ZS?view=chart
# /indicator/DT.DOD.DECT.GN.ZS?view=chart
# /indicator/DT.DOD.DECT.CD?view=chart
# /indicator/BX.KLT.DINV.CD.WD?view=chart
# /indicator/NY.GDP.MKTP.CD?view=chart
# /indicator/NY.GDP.MKTP.KD.ZG?view=chart
# /indicator/NY.GDP.PCAP.CD?view=chart
# /indicator/NY.GDP.PCAP.KD.ZG?view=chart
# /indicator/NY.GDP.PCAP.PP.CD?view=chart
# /indicator/NY.GNP.PCAP.CD?view=chart
# /indicator/NY.GNP.PCAP.PP.CD?view=chart
# /indicator/NY.GNP.ATLS.CD?view=chart
# /indicator/NY.GNP.MKTP.PP.CD?view=chart
# /indicator/BX.GRT.EXTA.CD.WD?view=chart
# /indicator/NE.GDI.TOTL.ZS?view=chart
# /indicator/NY.GNS.ICTR.ZS?view=chart
# /indicator/NE.IMP.GNFS.ZS?view=chart
# /indicator/NV.IND.TOTL.ZS?view=chart
# /indicator/NY.GDP.DEFL.KD.ZG?view=chart
# /indicator/FP.CPI.TOTL.ZG?view=chart
# /indicator/DT.ODA.ODAT.GN.ZS?view=chart
# /indicator/DT.ODA.ODAT.PC.ZS?view=chart
# /indicator/DT.ODA.ODAT.CD?view=chart
# /indicator/PA.NUS.PPP?view=chart
# /indicator/BX.TRF.PWKR.CD.DT?view=chart
# /indicator/PA.NUS.PPPC.RF?view=chart
# /indicator/GC.REV.XGRT.GD.ZS?view=chart
# /indicator/DT.DOD.DSTC.IR.ZS?view=chart
# /indicator/BX.GRT.TECH.CD.WD?view=chart
# /indicator/DT.TDS.DECT.EX.ZS?view=chart
# /indicator/FI.RES.TOTL.CD?view=chart
# /indicator/SE.PRM.UNER.FE?view=chart
# /indicator/SE.PRM.UNER.MA?view=chart
# /indicator/SE.XPD.TOTL.GD.ZS?view=chart
# /indicator/SE.XPD.TOTL.GB.ZS?view=chart
# /indicator/SE.XPD.PRIM.PC.ZS?view=chart
# /indicator/SE.XPD.SECO.PC.ZS?view=chart
# /indicator/SE.XPD.TERT.PC.ZS?view=chart
# /indicator/SE.PRM.GINT.FE.ZS?view=chart
# /indicator/SE.PRM.GINT.MA.ZS?view=chart
# /indicator/SL.TLF.TOTL.FE.ZS?view=chart
# /indicator/SL.TLF.TOTL.IN?view=chart
# /indicator/SE.ADT.LITR.FE.ZS?view=chart
# /indicator/SE.ADT.LITR.MA.ZS?view=chart
# /indicator/SE.ADT.LITR.ZS?view=chart
# /indicator/SE.ADT.1524.LT.FE.ZS?view=chart
# /indicator/SE.ADT.1524.LT.MA.ZS?view=chart
# /indicator/SE.ADT.1524.LT.ZS?view=chart
# /indicator/SE.PRM.PRSL.FE.ZS?view=chart
# /indicator/SE.PRM.PRSL.MA.ZS?view=chart
# /indicator/SP.POP.0014.TO.ZS?view=chart
# /indicator/SP.POP.1564.TO.ZS?view=chart
# /indicator/SE.PRM.CMPT.FE.ZS?view=chart
# /indicator/SE.PRM.CMPT.MA.ZS?view=chart
# /indicator/SE.PRM.CMPT.ZS?view=chart
# /indicator/SE.SEC.PROG.FE.ZS?view=chart
# /indicator/SE.SEC.PROG.MA.ZS?view=chart
# /indicator/SE.PRM.ENRL.TC.ZS?view=chart
# /indicator/SE.PRM.REPT.FE.ZS?view=chart
# /indicator/SE.PRM.REPT.MA.ZS?view=chart
# /indicator/SE.PRE.ENRR?view=chart
# /indicator/SE.PRM.ENRR?view=chart
# /indicator/SE.PRM.NENR?view=chart
# /indicator/SE.ENR.PRIM.FM.ZS?view=chart
# /indicator/SE.ENR.PRSC.FM.ZS?view=chart
# /indicator/SE.SEC.ENRR?view=chart
# /indicator/SE.SEC.NENR?view=chart
# /indicator/SE.TER.ENRR?view=chart
# /indicator/SE.PRM.TCAQ.ZS?view=chart
# /indicator/SL.UEM.TOTL.FE.ZS?view=chart
# /indicator/SL.UEM.TOTL.MA.ZS?view=chart
# /indicator/SL.UEM.TOTL.ZS?view=chart
# /indicator/EG.ELC.ACCS.ZS?view=chart
# /indicator/EG.USE.COMM.CL.ZS?view=chart
# /indicator/EG.USE.ELEC.KH.PC?view=chart
# /indicator/EG.IMP.CONS.ZS?view=chart
# /indicator/EG.EGY.PRIM.PP.KD?view=chart
# /indicator/EG.USE.PCAP.KG.OE?view=chart
# /indicator/EG.USE.COMM.FO.ZS?view=chart
# /indicator/TX.VAL.FUEL.ZS.UN?view=chart
# /indicator/EG.GDP.PUSE.KO.PP.KD?view=chart
# /indicator/IE.PPI.ENGY.CD?view=chart
# /indicator/TX.VAL.MMTL.ZS.UN?view=chart
# /indicator/EG.ELC.RNEW.ZS?view=chart
# /indicator/EG.FEC.RNEW.ZS?view=chart
# /indicator/IC.ELC.TIME?view=chart
# /indicator/NY.GDP.TOTL.RT.ZS?view=chart
# /indicator/EG.ELC.ACCS.ZS?view=chart
# /indicator/NY.ADJ.SVNG.GN.ZS?view=chart
# /indicator/AG.LND.AGRI.ZS?view=chart
# /indicator/ER.H2O.FWTL.ZS?view=chart
# /indicator/ER.H2O.FWTL.K3?view=chart
# /indicator/AG.LND.ARBL.ZS?view=chart
# /indicator/EN.BIR.THRD.NO?view=chart
# /indicator/EN.ATM.CO2E.KT?view=chart
# /indicator/EN.ATM.CO2E.PC?view=chart
# /indicator/EG.EGY.PRIM.PP.KD?view=chart
# /indicator/EN.FSH.THRD.NO?view=chart
# /indicator/AG.LND.FRST.ZS?view=chart
# /indicator/AG.LND.FRST.K2?view=chart
# /indicator/AG.LND.TOTL.K2?view=chart
# /indicator/AG.LND.EL5M.ZS?view=chart
# /indicator/EN.MAM.THRD.NO?view=chart
# /indicator/EN.ATM.METH.KT.CE?view=chart
# /indicator/EN.ATM.NOXE.KT.CE?view=chart
# /indicator/EN.ATM.PM25.MC.M3?view=chart
# /indicator/EN.ATM.PM25.MC.ZS?view=chart
# /indicator/EN.HPT.THRD.NO?view=chart
# /indicator/EN.POP.EL5M.ZS?view=chart
# /indicator/EN.POP.SLUM.UR.ZS?view=chart
# /indicator/EG.ELC.RNEW.ZS?view=chart
# /indicator/EG.FEC.RNEW.ZS?view=chart
# /indicator/ER.H2O.INTR.PC?view=chart
# /indicator/ER.H2O.INTR.K3?view=chart
# /indicator/AG.SRF.TOTL.K2?view=chart
# /indicator/ER.PTD.TOTL.ZS?view=chart
# /indicator/EN.ATM.GHGT.KT.CE?view=chart
# /indicator/NY.GDP.TOTL.RT.ZS?view=chart
# /indicator/BN.CAB.XOKA.CD?view=chart
# /indicator/DT.DOD.DECT.GN.ZS?view=chart
# /indicator/DT.DOD.DPNG.CD?view=chart
# /indicator/DT.DOD.DPPG.CD?view=chart
# /indicator/DT.DOD.DSTC.CD?view=chart
# /indicator/DT.DOD.DECT.CD?view=chart
# /indicator/BX.KLT.DINV.CD.WD?view=chart
# /indicator/BX.GRT.EXTA.CD.WD?view=chart
# /indicator/DT.DOD.MWBG.CD?view=chart
# /indicator/DT.ODA.ODAT.GN.ZS?view=chart
# /indicator/DT.ODA.ODAT.PC.ZS?view=chart
# /indicator/DT.ODA.ODAT.CD?view=chart
# /indicator/BX.TRF.PWKR.CD.DT?view=chart
# /indicator/DT.DOD.DSTC.IR.ZS?view=chart
# /indicator/BX.GRT.TECH.CD.WD?view=chart
# /indicator/DT.TDS.DECT.EX.ZS?view=chart
# /indicator/FI.RES.TOTL.CD?view=chart
# /indicator/DT.DOD.DIMF.CD?view=chart
# /indicator/FB.ATM.TOTL.P5?view=chart
# /indicator/FB.BNK.CAPA.ZS?view=chart
# /indicator/FB.AST.NPER.ZS?view=chart
# /indicator/FM.LBL.BMNY.GD.ZS?view=chart
# /indicator/FM.LBL.BMNY.ZG?view=chart
# /indicator/FB.CBK.BRCH.P5?view=chart
# /indicator/FR.INR.DPST?view=chart
# /indicator/IC.CRD.INFO.XQ?view=chart
# /indicator/FS.AST.DOMS.GD.ZS?view=chart
# /indicator/FS.AST.PRVT.GD.ZS?view=chart
# /indicator/BX.KLT.DINV.CD.WD?view=chart
# /indicator/FP.CPI.TOTL.ZG?view=chart
# /indicator/FR.INR.LNDP?view=chart
# /indicator/SM.POP.TOTL?view=chart
# /indicator/FR.INR.LEND?view=chart
# /indicator/CM.MKT.LDOM.NO?view=chart
# /indicator/CM.MKT.LCAP.GD.ZS?view=chart
# /indicator/CM.MKT.LCAP.CD?view=chart
# /indicator/SM.POP.NETM?view=chart
# /indicator/PA.NUS.FCRF?view=chart
# /indicator/BX.TRF.PWKR.CD.DT?view=chart
# /indicator/FR.INR.RINR?view=chart
# /indicator/FR.INR.RISK?view=chart
# /indicator/CM.MKT.INDX.ZG?view=chart
# /indicator/CM.MKT.TRAD.GD.ZS?view=chart
# /indicator/CM.MKT.TRNR?view=chart
# /indicator/IC.LGL.CRED.XQ?view=chart
# /indicator/FI.RES.TOTL.CD?view=chart
# /indicator/SP.ADO.TFRT?view=chart
# /indicator/SH.STA.BRTC.ZS?view=chart
# /indicator/SL.TLF.0714.FE.ZS?view=chart
# /indicator/SL.TLF.0714.MA.ZS?view=chart
# /indicator/SE.PRM.UNER.FE?view=chart
# /indicator/SE.PRM.UNER.MA?view=chart
# /indicator/SP.DYN.CONU.ZS?view=chart
# /indicator/SL.FAM.WORK.FE.ZS?view=chart
# /indicator/SL.FAM.WORK.MA.ZS?view=chart
# /indicator/SL.AGR.EMPL.FE.ZS?view=chart
# /indicator/SL.AGR.EMPL.MA.ZS?view=chart
# /indicator/SL.IND.EMPL.FE.ZS?view=chart
# /indicator/SL.IND.EMPL.MA.ZS?view=chart
# /indicator/SL.SRV.EMPL.FE.ZS?view=chart
# /indicator/SL.SRV.EMPL.MA.ZS?view=chart
# /indicator/SP.DYN.TFRT.IN?view=chart
# /indicator/IC.FRM.FEMO.ZS?view=chart
# /indicator/IC.FRM.FEMM.ZS?view=chart
# /indicator/SE.PRM.GINT.FE.ZS?view=chart
# /indicator/SE.PRM.GINT.MA.ZS?view=chart
# /indicator/SL.TLF.CACT.FE.ZS?view=chart
# /indicator/SL.TLF.CACT.MA.ZS?view=chart
# /indicator/SL.TLF.TOTL.FE.ZS?view=chart
# /indicator/SP.DYN.LE00.FE.IN?view=chart
# /indicator/SP.DYN.LE00.MA.IN?view=chart
# /indicator/SE.ADT.LITR.FE.ZS?view=chart
# /indicator/SE.ADT.LITR.MA.ZS?view=chart
# /indicator/SE.ADT.1524.LT.FE.ZS?view=chart
# /indicator/SE.ADT.1524.LT.MA.ZS?view=chart
# /indicator/SH.STA.MMRT?view=chart
# /indicator/SG.NOD.CONS?view=chart
# /indicator/SE.PRM.PRSL.FE.ZS?view=chart
# /indicator/SE.PRM.PRSL.MA.ZS?view=chart
# /indicator/SH.STA.ANVC.ZS?view=chart
# /indicator/SH.HIV.1524.FE.ZS?view=chart
# /indicator/SH.HIV.1524.MA.ZS?view=chart
# /indicator/SE.PRM.CMPT.FE.ZS?view=chart
# /indicator/SE.PRM.CMPT.MA.ZS?view=chart
# /indicator/SE.SEC.PROG.FE.ZS?view=chart
# /indicator/SE.SEC.PROG.MA.ZS?view=chart
# /indicator/SG.GEN.PARL.ZS?view=chart
# /indicator/SG.TIM.UWRK.FE?view=chart
# /indicator/SG.TIM.UWRK.MA?view=chart
# /indicator/SE.PRM.REPT.FE.ZS?view=chart
# /indicator/SE.PRM.REPT.MA.ZS?view=chart
# /indicator/SE.ENR.PRIM.FM.ZS?view=chart
# /indicator/SE.ENR.PRSC.FM.ZS?view=chart
# /indicator/SP.MTR.1519.ZS?view=chart
# /indicator/SL.UEM.TOTL.FE.ZS?view=chart
# /indicator/SL.UEM.TOTL.MA.ZS?view=chart
# /indicator/SL.UEM.1524.FE.ZS?view=chart
# /indicator/SL.UEM.1524.MA.ZS?view=chart
# /indicator/SL.EMP.VULN.FE.ZS?view=chart
# /indicator/SL.EMP.VULN.MA.ZS?view=chart
# /indicator/SL.EMP.WORK.FE.ZS?view=chart
# /indicator/SL.EMP.WORK.MA.ZS?view=chart
# /indicator/SG.DMK.SRCR.FN.ZS?view=chart
# /indicator/SP.ADO.TFRT?view=chart
# /indicator/SP.POP.DPND?view=chart
# /indicator/SP.DYN.CBRT.IN?view=chart
# /indicator/SH.STA.BRTC.ZS?view=chart
# /indicator/SH.DTH.COMM.ZS?view=chart
# /indicator/SH.DTH.INJR.ZS?view=chart
# /indicator/SH.DTH.NCOM.ZS?view=chart
# /indicator/SP.REG.BRTH.ZS?view=chart
# /indicator/SP.REG.DTHS.ZS?view=chart
# /indicator/SP.DYN.CONU.ZS?view=chart
# /indicator/SP.DYN.CDRT.IN?view=chart
# /indicator/SH.STA.DIAB.ZS?view=chart
# /indicator/SP.DYN.TFRT.IN?view=chart
# /indicator/SH.MED.BEDS.ZS?view=chart
# /indicator/SH.IMM.IDPT?view=chart
# /indicator/SH.IMM.MEAS?view=chart
# /indicator/SH.TBS.INCD?view=chart
# /indicator/SM.POP.TOTL?view=chart
# /indicator/SP.DYN.LE00.FE.IN?view=chart
# /indicator/SP.DYN.LE00.MA.IN?view=chart
# /indicator/SP.DYN.LE00.IN?view=chart
# /indicator/SH.STA.MMRT?view=chart
# /indicator/SH.STA.TRAF.P5?view=chart
# /indicator/SP.DYN.IMRT.IN?view=chart
# /indicator/SH.DYN.NMRT?view=chart
# /indicator/SH.DYN.MORT?view=chart
# /indicator/SM.POP.NETM?view=chart
# /indicator/SH.SGR.PROC.P5?view=chart
# /indicator/SP.POP.0014.TO.ZS?view=chart
# /indicator/SP.POP.1564.TO.ZS?view=chart
# /indicator/SP.POP.65UP.TO.ZS?view=chart
# /indicator/SP.POP.GROW?view=chart
# /indicator/SP.POP.TOTL.FE.ZS?view=chart
# /indicator/SP.POP.TOTL?view=chart
# /indicator/SH.STA.ANVC.ZS?view=chart
# /indicator/SH.HIV.1524.FE.ZS?view=chart
# /indicator/SH.HIV.1524.MA.ZS?view=chart
# /indicator/SH.DYN.AIDS.ZS?view=chart
# /indicator/SH.ANM.CHLD.ZS?view=chart
# /indicator/SH.STA.OWGH.ZS?view=chart
# /indicator/SH.SVR.WAST.ZS?view=chart
# /indicator/SH.STA.STNT.ZS?view=chart
# /indicator/SN.ITK.DEFC.ZS?view=chart
# /indicator/SH.STA.MALN.ZS?view=chart
# /indicator/SH.STA.WAST.ZS?view=chart
# /indicator/SM.POP.REFG?view=chart
# /indicator/SM.POP.REFG.OR?view=chart
# /indicator/SH.SGR.CRSK.ZS?view=chart
# /indicator/SH.SGR.IRSK.ZS?view=chart
# /indicator/SH.MED.SAOP.P5?view=chart
# /indicator/SP.MTR.1519.ZS?view=chart
# /indicator/SP.UWT.TFRT?view=chart
# /indicator/IS.AIR.DPRT?view=chart
# /indicator/ER.H2O.FWTL.ZS?view=chart
# /indicator/ER.H2O.FWTL.K3?view=chart
# /indicator/IS.SHP.GOOD.TU?view=chart
# /indicator/EG.USE.ELEC.KH.PC?view=chart
# /indicator/IT.NET.BBND.P2?view=chart
# /indicator/IT.MLT.MAIN.P2?view=chart
# /indicator/IE.PPI.ENGY.CD?view=chart
# /indicator/IE.PPI.TRAN.CD?view=chart
# /indicator/IE.PPI.WATR.CD?view=chart
# /indicator/IT.CEL.SETS.P2?view=chart
# /indicator/IS.RRS.TOTL.KM?view=chart
# /indicator/ER.H2O.INTR.PC?view=chart
# /indicator/ER.H2O.INTR.K3?view=chart
# /indicator/IT.NET.SECR.P6?view=chart
# /indicator/SI.SPR.PC40.ZG?view=chart
# /indicator/SI.SPR.PCAP.ZG?view=chart
# /indicator/SI.POV.GINI?view=chart
# /indicator/SI.DST.04TH.20?view=chart
# /indicator/SI.DST.10TH.10?view=chart
# /indicator/SI.DST.05TH.20?view=chart
# /indicator/SI.DST.FRST.10?view=chart
# /indicator/SI.DST.FRST.20?view=chart
# /indicator/SI.DST.02ND.20?view=chart
# /indicator/SI.DST.03RD.20?view=chart
# /indicator/EN.POP.SLUM.UR.ZS?view=chart
# /indicator/SI.POV.GAPS?view=chart
# /indicator/SI.POV.NAGP?view=chart
# /indicator/SI.POV.DDAY?view=chart
# /indicator/SI.POV.NAHC?view=chart
# /indicator/SI.POV.RUGP?view=chart
# /indicator/SI.POV.RUHC?view=chart
# /indicator/SI.SPR.PC40?view=chart
# /indicator/SI.SPR.PCAP?view=chart
# /indicator/SI.POV.URGP?view=chart
# /indicator/SI.POV.URHC?view=chart
# /indicator/IC.BUS.DISC.XQ?view=chart
# /indicator/IC.CRD.INFO.XQ?view=chart
# /indicator/FS.AST.PRVT.GD.ZS?view=chart
# /indicator/IC.BUS.EASE.XQ?view=chart
# /indicator/IC.FRM.BKWC.ZS?view=chart
# /indicator/IC.FRM.FEMO.ZS?view=chart
# /indicator/IC.FRM.FEMM.ZS?view=chart
# /indicator/TX.VAL.FUEL.ZS.UN?view=chart
# /indicator/TX.VAL.TECH.MF.ZS?view=chart
# /indicator/TX.VAL.TECH.CD?view=chart
# /indicator/ST.INT.XPND.MP.ZS?view=chart
# /indicator/ST.INT.RCPT.XP.ZS?view=chart
# /indicator/IE.PPI.ENGY.CD?view=chart
# /indicator/IE.PPI.TRAN.CD?view=chart
# /indicator/IE.PPI.WATR.CD?view=chart
# /indicator/LP.EXP.DURS.MD?view=chart
# /indicator/LP.IMP.DURS.MD?view=chart
# /indicator/LP.LPI.OVRL.XQ?view=chart
# /indicator/TX.VAL.MRCH.CD.WT?view=chart
# /indicator/TM.VAL.MRCH.CD.WT?view=chart
# /indicator/TG.VAL.TOTL.GD.ZS?view=chart
# /indicator/TT.PRI.MRCH.XD.WD?view=chart
# /indicator/IC.BUS.NREG?view=chart
# /indicator/TX.VAL.MMTL.ZS.UN?view=chart
# /indicator/IC.REG.PROC?view=chart
# /indicator/IC.REG.PROC.FE?view=chart
# /indicator/IC.REG.PROC.MA?view=chart
# /indicator/IC.LGL.CRED.XQ?view=chart
# /indicator/IC.ELC.TIME?view=chart
# /indicator/IC.REG.DURS?view=chart
# /indicator/IC.REG.DURS.FE?view=chart
# /indicator/IC.REG.DURS.MA?view=chart
# /indicator/IC.GOV.DURS.ZS?view=chart
# /indicator/IC.TAX.TOTL.CP.ZS?view=chart
# /indicator/IQ.CPA.ECON.XQ?view=chart
# /indicator/IQ.CPA.SOCI.XQ?view=chart
# /indicator/IQ.CPA.PUBS.XQ?view=chart
# /indicator/IQ.CPA.STRC.XQ?view=chart
# /indicator/GC.DOD.TOTL.GD.ZS?view=chart
# /indicator/GC.XPN.TOTL.GD.ZS?view=chart
# /indicator/IQ.CPA.IRAI.XQ?view=chart
# /indicator/VC.IHR.PSRC.P5?view=chart
# /indicator/MS.MIL.XPND.GD.ZS?view=chart
# /indicator/MS.MIL.XPND.ZS?view=chart
# /indicator/GC.AST.TOTL.GD.ZS?view=chart
# /indicator/GC.LBL.TOTL.GD.ZS?view=chart
# /indicator/GC.NFN.TOTL.GD.ZS?view=chart
# /indicator/GC.NLD.TOTL.GD.ZS?view=chart
# /indicator/SG.NOD.CONS?view=chart
# /indicator/SG.GEN.PARL.ZS?view=chart
# /indicator/GC.REV.XGRT.GD.ZS?view=chart
# /indicator/IQ.SCI.OVRL?view=chart
# /indicator/IC.LGL.CRED.XQ?view=chart
# /indicator/GC.TAX.TOTL.GD.ZS?view=chart
# /indicator/IC.TAX.TOTL.CP.ZS?view=chart
# /indicator/BM.GSR.ROYL.CD?view=chart
# /indicator/BX.GSR.ROYL.CD?view=chart
# /indicator/TX.VAL.TECH.MF.ZS?view=chart
# /indicator/TX.VAL.TECH.CD?view=chart
# /indicator/IP.PAT.NRES?view=chart
# /indicator/IP.PAT.RESD?view=chart
# /indicator/GB.XPD.RSDV.GD.ZS?view=chart
# /indicator/SP.POP.SCIE.RD.P6?view=chart
# /indicator/IP.JRN.ARTC.SC?view=chart
# /indicator/SP.POP.TECH.RD.P6?view=chart
# /indicator/IP.TMK.NRES?view=chart
# /indicator/IP.TMK.RESD?view=chart
# /indicator/SP.ADO.TFRT?view=chart
# /indicator/SL.TLF.0714.FE.ZS?view=chart
# /indicator/SL.TLF.0714.MA.ZS?view=chart
# /indicator/SL.TLF.0714.ZS?view=chart
# /indicator/SL.TLF.CACT.FE.ZS?view=chart
# /indicator/SL.TLF.CACT.MA.ZS?view=chart
# /indicator/SP.DYN.LE00.FE.IN?view=chart
# /indicator/SP.DYN.LE00.MA.IN?view=chart
# /indicator/SH.HIV.1524.FE.ZS?view=chart
# /indicator/SH.HIV.1524.MA.ZS?view=chart
# /indicator/SG.GEN.PARL.ZS?view=chart
# /indicator/SM.POP.REFG?view=chart
# /indicator/SM.POP.REFG.OR?view=chart
# /indicator/SE.ENR.PRIM.FM.ZS?view=chart
# /indicator/SE.ENR.PRSC.FM.ZS?view=chart
# /indicator/SL.UEM.TOTL.FE.ZS?view=chart
# /indicator/SL.UEM.TOTL.MA.ZS?view=chart
# /indicator/SL.EMP.VULN.FE.ZS?view=chart
# /indicator/SL.EMP.VULN.MA.ZS?view=chart
# /indicator/SL.TLF.0714.FE.ZS?view=chart
# /indicator/SL.TLF.0714.MA.ZS?view=chart
# /indicator/SL.TLF.0714.ZS?view=chart
# /indicator/SL.FAM.WORK.FE.ZS?view=chart
# /indicator/SL.FAM.WORK.MA.ZS?view=chart
# /indicator/SL.AGR.EMPL.FE.ZS?view=chart
# /indicator/SL.AGR.EMPL.MA.ZS?view=chart
# /indicator/SL.IND.EMPL.FE.ZS?view=chart
# /indicator/SL.IND.EMPL.MA.ZS?view=chart
# /indicator/SL.SRV.EMPL.FE.ZS?view=chart
# /indicator/SL.SRV.EMPL.MA.ZS?view=chart
# /indicator/SL.EMP.TOTL.SP.ZS?view=chart
# /indicator/SL.GDP.PCAP.EM.KD?view=chart
# /indicator/SL.TLF.CACT.FE.ZS?view=chart
# /indicator/SL.TLF.CACT.MA.ZS?view=chart
# /indicator/SL.TLF.TOTL.FE.ZS?view=chart
# /indicator/SL.TLF.TOTL.IN?view=chart
# /indicator/SL.UEM.TOTL.FE.ZS?view=chart
# /indicator/SL.UEM.TOTL.MA.ZS?view=chart
# /indicator/SL.UEM.TOTL.ZS?view=chart
# /indicator/SL.UEM.1524.FE.ZS?view=chart
# /indicator/SL.UEM.1524.MA.ZS?view=chart
# /indicator/SL.EMP.VULN.FE.ZS?view=chart
# /indicator/SL.EMP.VULN.MA.ZS?view=chart
# /indicator/SL.EMP.WORK.FE.ZS?view=chart
# /indicator/SL.EMP.WORK.MA.ZS?view=chart
# /indicator/EG.IMP.CONS.ZS?view=chart
# /indicator/NE.EXP.GNFS.ZS?view=chart
# /indicator/TX.VAL.FUEL.ZS.UN?view=chart
# /indicator/TX.VAL.TECH.MF.ZS?view=chart
# /indicator/TX.VAL.TECH.CD?view=chart
# /indicator/NE.IMP.GNFS.ZS?view=chart
# /indicator/ST.INT.XPND.MP.ZS?view=chart
# /indicator/ST.INT.RCPT.XP.ZS?view=chart
# /indicator/LP.EXP.DURS.MD?view=chart
# /indicator/LP.IMP.DURS.MD?view=chart
# /indicator/LP.LPI.OVRL.XQ?view=chart
# /indicator/TX.VAL.MRCH.CD.WT?view=chart
# /indicator/TM.VAL.MRCH.CD.WT?view=chart
# /indicator/TG.VAL.TOTL.GD.ZS?view=chart
# /indicator/TT.PRI.MRCH.XD.WD?view=chart
# /indicator/TX.VAL.MMTL.ZS.UN?view=chart
# /indicator/SH.STA.TRAF.P5?view=chart
# /indicator/EN.ATM.PM25.MC.M3?view=chart
# /indicator/EN.ATM.PM25.MC.ZS?view=chart
# /indicator/EN.POP.DNST?view=chart
# /indicator/EN.URB.LCTY.UR.ZS?view=chart
# /indicator/EN.URB.MCTY.TL.ZS?view=chart
# /indicator/EN.POP.SLUM.UR.ZS?view=chart
# /indicator/SP.URB.TOTL?view=chart
# /indicator/SP.URB.TOTL.IN.ZS?view=chart
# /indicator/SI.POV.URGP?view=chart
# /indicator/SI.POV.URHC?view=chart
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-3e848947e2b5> in <module>
#       5
#       6     try:
# ----> 7         indicator = result.a["href"]
#       8
#       9         if "view=chart" in indicator:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Transforming data by splitting and splicing

indicator_code_list = []
for indicator in indicator_list:
    slice_indicator = indicator[11:]
    split_indicator = slice_indicator.split("?")
    indicator_code = split_indicator[0]
    indicator_code_list.append(indicator_code)
    # print(indicator_code_list)

# %%
# Extracting XML API with for loops to transform it into...
# ... lists to fill a pandas DF

country_name = []
country_code = []
ind_code = []
year = []
value = []

for country in country_id:
    for indicator_code in indicator_code_list:   
        query_url = "http://api.worldbank.org/v2/country/" + country + "/indicator/" + indicator_code + "?date=" + date        
        r = requests.get(query_url)
        root = ET.fromstring(r.text)
        
        for child in root:
            country_name.append(child[1].text)
            country_code.append(child[2].text)
            ind_code.append(child[0].attrib["id"])
            year.append(child[3].text)
            value.append(child[4].text)

# %%
value_xml_df = pd.DataFrame({"country_name": country_name, 
                          "country_code": country_code,
                         "indicator_code": ind_code,
                         "value": value,
                         "year": year})

# %%
value_table1= value_xml_df.dropna()
value_table1
# Out:
#             country_name country_code     indicator_code              value  \
# 7          United States          USA     AG.LND.AGRI.ZS   44.3690679995015
# 14         United States          USA     NV.AGR.TOTL.ZS   0.91647931957252
# 15         United States          USA     NV.AGR.TOTL.ZS  0.940404125890274
# 19         United States          USA     AG.LND.ARBL.ZS   16.6454038406458
# 23         United States          USA  AG.LND.ARBL.HA.PC   0.47129683201675
# 26         United States          USA     AG.YLD.CREL.KG             8280.8
# 27         United States          USA     AG.YLD.CREL.KG             8144.6
# 31         United States          USA     AG.PRD.CROP.XD             122.19
# 32         United States          USA  SL.AGR.EMPL.FE.ZS  0.742999970912933
# 33         United States          USA  SL.AGR.EMPL.FE.ZS  0.754999995231628
# 34         United States          USA  SL.AGR.EMPL.FE.ZS  0.767000019550323
# 35         United States          USA  SL.AGR.EMPL.FE.ZS  0.774999976158142
# 36         United States          USA  SL.AGR.EMPL.MA.ZS   1.97800004482269
# 37         United States          USA  SL.AGR.EMPL.MA.ZS   1.99300003051758
# 38         United States          USA  SL.AGR.EMPL.MA.ZS   2.00399994850159
# 39         United States          USA  SL.AGR.EMPL.MA.ZS   2.01600003242493
# 43         United States          USA     AG.CON.FERT.ZS   138.594847713652
# 47         United States          USA     AG.PRD.FOOD.XD             122.32
# 51         United States          USA     AG.LND.FRST.ZS   33.9297856663409
# 55         United States          USA     AG.LND.FRST.K2            3103700
# 57         United States          USA     AG.LND.TOTL.K2            9147420
# 58         United States          USA     AG.LND.TOTL.K2            9147420
# 59         United States          USA     AG.LND.TOTL.K2            9147420
# 62         United States          USA     AG.LND.CREL.HA           53149164
# 63         United States          USA     AG.LND.CREL.HA           58438795
# 67         United States          USA     AG.PRD.LVSK.XD              109.7
# 71         United States          USA     AG.LND.CROP.ZS  0.284233149893631
# 73         United States          USA        SP.RUR.TOTL           58052589
# 74         United States          USA        SP.RUR.TOTL           58337896
# 75         United States          USA        SP.RUR.TOTL           58598680
# ...                  ...          ...                ...                ...
# 6315  Russian Federation          RUS  TM.VAL.MRCH.CD.WT       191493000000
# 6317  Russian Federation          RUS  TG.VAL.TOTL.GD.ZS   41.8123771178046
# 6318  Russian Federation          RUS  TG.VAL.TOTL.GD.ZS   37.4803612064242
# 6319  Russian Federation          RUS  TG.VAL.TOTL.GD.ZS   36.8904802475228
# 6321  Russian Federation          RUS  TT.PRI.MRCH.XD.WD        168.8628627
# 6322  Russian Federation          RUS  TT.PRI.MRCH.XD.WD        144.0910861
# 6323  Russian Federation          RUS  TT.PRI.MRCH.XD.WD        127.3568336
# 6325  Russian Federation          RUS  TX.VAL.MMTL.ZS.UN   5.53964071717589
# 6326  Russian Federation          RUS  TX.VAL.MMTL.ZS.UN   5.96973486545961
# 6327  Russian Federation          RUS  TX.VAL.MMTL.ZS.UN   6.19271142581755
# 6331  Russian Federation          RUS     SH.STA.TRAF.P5                 18
# 6334  Russian Federation          RUS  EN.ATM.PM25.MC.M3   16.1602238064949
# 6335  Russian Federation          RUS  EN.ATM.PM25.MC.M3   16.2198897101318
# 6338  Russian Federation          RUS  EN.ATM.PM25.MC.ZS   91.6093290043281
# 6339  Russian Federation          RUS  EN.ATM.PM25.MC.ZS   91.7079917953348
# 6341  Russian Federation          RUS        EN.POP.DNST   8.82207955488442
# 6342  Russian Federation          RUS        EN.POP.DNST   8.82322079860193
# 6343  Russian Federation          RUS        EN.POP.DNST    8.8137962870805
# 6345  Russian Federation          RUS  EN.URB.LCTY.UR.ZS   11.5397185738909
# 6346  Russian Federation          RUS  EN.URB.LCTY.UR.ZS     11.44715433189
# 6347  Russian Federation          RUS  EN.URB.LCTY.UR.ZS   11.3669931820238
# 6349  Russian Federation          RUS  EN.URB.MCTY.TL.ZS   23.1913304477739
# 6350  Russian Federation          RUS  EN.URB.MCTY.TL.ZS   22.9703957334954
# 6351  Russian Federation          RUS  EN.URB.MCTY.TL.ZS   22.7791930237877
# 6357  Russian Federation          RUS        SP.URB.TOTL          107539347
# 6358  Russian Federation          RUS        SP.URB.TOTL          107349518
# 6359  Russian Federation          RUS        SP.URB.TOTL          107050095
# 6361  Russian Federation          RUS  SP.URB.TOTL.IN.ZS             74.433
# 6362  Russian Federation          RUS  SP.URB.TOTL.IN.ZS             74.292
# 6363  Russian Federation          RUS  SP.URB.TOTL.IN.ZS             74.164
#
#       year
# 7     2016
# 14    2017
# 15    2016
# 19    2016
# 23    2016
# 26    2017
# 27    2016
# 31    2016
# 32    2019
# 33    2018
# 34    2017
# 35    2016
# 36    2019
# 37    2018
# 38    2017
# 39    2016
# 43    2016
# 47    2016
# 51    2016
# 55    2016
# 57    2018
# 58    2017
# 59    2016
# 62    2017
# 63    2016
# 67    2016
# 71    2016
# 73    2018
# 74    2017
# 75    2016
# ...    ...
# 6315  2016
# 6317  2018
# 6318  2017
# 6319  2016
# 6321  2018
# 6322  2017
# 6323  2016
# 6325  2018
# 6326  2017
# 6327  2016
# 6331  2016
# 6334  2017
# 6335  2016
# 6338  2017
# 6339  2016
# 6341  2018
# 6342  2017
# 6343  2016
# 6345  2018
# 6346  2017
# 6347  2016
# 6349  2018
# 6350  2017
# 6351  2016
# 6357  2018
# 6358  2017
# 6359  2016
# 6361  2018
# 6362  2017
# 6363  2016
#
# [2861 rows x 5 columns]

# %%
#Load Dataframe into databases
value_csv_df.to_sql(name='values', con=engine, if_exists='append', index=False)

# %%
value_table1.to_sql(name='values_1', con=engine, if_exists='append', index=False)

# %%
ind_df.to_sql(name='indicators', con=engine, if_exists='append', index=False)

# %%
countries.to_sql(name='countries', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from values', con=engine).head()
# Out:
#   country_name country_code  indicator_code      value  year
# 0        China          CHN     SP.ADO.TFRT  68.033200  1960
# 1        China          CHN     SP.POP.DPND  77.322072  1960
# 2        China          CHN  SP.POP.DPND.OL   6.472535  1960
# 3        China          CHN  SP.POP.DPND.YG  70.849537  1960
# 4        China          CHN  NV.AGR.TOTL.ZS  23.383665  1960

# %%
pd.read_sql_query('select * from values_1', con=engine).head()
# Out:
#     country_name country_code     indicator_code              value  year
# 0  United States          USA     AG.LND.AGRI.ZS   44.3690679995015  2016
# 1  United States          USA     NV.AGR.TOTL.ZS   0.91647931957252  2017
# 2  United States          USA     NV.AGR.TOTL.ZS  0.940404125890274  2016
# 3  United States          USA     AG.LND.ARBL.ZS   16.6454038406458  2016
# 4  United States          USA  AG.LND.ARBL.HA.PC   0.47129683201675  2016

# %%
pd.read_sql_query('select * from indicators', con=engine).head()
# Out:
#                                       indicator_name  indicator_code
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1  Age dependency ratio (% of working-age populat...     SP.POP.DPND
# 2  Age dependency ratio, old (% of working-age po...  SP.POP.DPND.OL
# 3  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 4        Arms exports (SIPRI trend indicator values)  MS.MIL.XPRT.KD

# %%
pd.read_sql_query('select * from countries', con=engine).head()
# Out:
#   country_code        country_name
# 0          USA       United States
# 1          CHN               China
# 2          RUS  Russian Federation
